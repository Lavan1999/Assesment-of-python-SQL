# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavan1999/Assesment-of-python-SQL/blob/main/GIFusion_Assesment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python: Next Permutation

# %%
from typing import List

class Solution:
    def nextPermutation(self, nums: List[int]):
        n = len(nums)

        # Step 1: Find the first decreasing element from the end
        i = n - 2
        while i >= 0 and nums[i] >= nums[i + 1]:
            i -= 1

        if i >= 0:
            # Step 2: Find the next larger element from the end and swap
            j = n - 1
            while nums[j] <= nums[i]:
                j -= 1
            nums[i], nums[j] = nums[j], nums[i]

        # Step 3: Reverse the sequence after i
        nums[i + 1:] = reversed(nums[i + 1:])

# Example usage
nums = [1, 2, 3]
Solution().nextPermutation(nums)
print(nums)  # Output: [1, 3, 2]
# Out:
# [1, 3, 2]

# %% [markdown]
# SQL: Consecutive Numbers

# %%
# Write your MySQL query statement below
WITH LogsNeighbors AS (
SELECT *,
    LAG(num) OVER(ORDER BY id) AS previous_num,
    LEAD(num) OVER(ORDER BY id) AS next_num
    FROM LOGS
  )
SELECT DISTINCT num AS ConsecutiveNums
FROM LogsNeighbors
WHERE num = previous_num AND num = next_num;

# %% [markdown]
# ![Screenshot (399).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (398).png](data:image/png;base64,...)
